# %%
import pandas as pd
import os
from matplotlib import pyplot as plt
import datetime
import numpy as np

# %%
AIS_data_dir = '/Volumes/Ocean_Acoustics/AIS_Data/Axial_Seamount/'
files = os.listdir(AIS_data_dir)

# %%
for file in files:
    try:
        df
    except NameError:
        df = pd.read_csv(AIS_data_dir + file)
    else:
        df = pd.concat([pd.read_csv(AIS_data_dir + file), df])

# %%
# Out:
#             MMSI        IMO  STATUS  SPEED (KNOTSx10)       LAT       LON  \
# 0      369272000  9206114.0       0               132  45.05585 -129.9805
# 1      563673000  9689160.0       0               114  46.40802 -130.5953
# 2      356159000        NaN       0               131  46.54730 -129.6827
# 3      563673000  9689160.0       0               113  46.40329 -130.5711
# 4      369272000  9206114.0       0               133  45.02689 -129.9556
# ...          ...        ...     ...               ...       ...       ...
# 63176  369272000  9206114.0       0               133  45.09314 -130.0125
# 63177  356159000  9382061.0       0               129  46.51588 -129.6001
# 63178  563673000  9689160.0       0               114  46.42135 -130.6508
# 63179  563673000  9689160.0       0               114  46.41515 -130.6248
# 63180  563673000  9689160.0       0               114  46.41211 -130.6125
#
#        COURSE  HEADING        TIMESTAMP UTC
# ...

# %%
times = df['TIMESTAMP UTC'].to_numpy()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-d37ea65b37be> in <module>
# ----> 1 times = np.datetime64(df['TIMESTAMP UTC'].to_numpy())
#
# ValueError: Could not convert object to NumPy datetime

# %%
time_hist = np.histogram(times)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-ea6d0066d55e> in <module>
# ----> 1 time_hist = np.histogram(times)
#
# <__array_function__ internals> in histogram(*args, **kwargs)
#
# ~/opt/anaconda3/envs/ooi_dev/lib/python3.7/site-packages/numpy/lib/histograms.py in histogram(a, bins, range, normed, weights, density)
#     793     a, weights = _ravel_and_check_weights(a, weights)
#     794
# --> 795     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     796
#     797     # Histogram is an integer or a float array depending on the weights.
#
# ~/opt/anaconda3/envs/ooi_dev/lib/python3.7/site-packages/numpy/lib/histograms.py in _get_bin_edges(a, bins, range, weights)
#     427             raise ValueError('`bins` must be positive, when an integer')
#     428
# --> 429         first_edge, last_edge = _get_outer_edges(a, range)
#     430
# ...

# %%
for k in range(len(time)):
    time[k] = datetime.datetime.strptime(time_str[k], '%Y-%m-%d %H:%M:%S')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-0c13342902c5> in <module>
#       1 for k in range(len(time)):
# ----> 2     time[k] = datetime.datetime.strptime(time_str[k], '%Y-%m-%d %H:%M:%S')
#
# TypeError: strptime() argument 1 must be str, not datetime.datetime
