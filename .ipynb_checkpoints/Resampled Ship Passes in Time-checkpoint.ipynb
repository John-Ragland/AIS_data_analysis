# %% [markdown]
# # Resampled ship passes in time
# - break AIS data up into discrete ship sample events
# - uniformly resample each ship pass (using linear interpolation)

# %%
import pandas as pd
import os
from matplotlib import pyplot as plt
import datetime
import numpy as np
import seaborn as sns
import datetime
import plotly.express as px
import plotly
import plotly.graph_objects as go
import pickle
import AIS_tools
import scipy
import pickle
import math as m
import geopy

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
# Get raw AIS data
df = AIS_tools.get_AIS_data()

# %%
# Break data into list of ship passes
ship_passes, pass_start_idxs = AIS_tools.single_ship_pass(df, load_pickle=True)

# %%
# Uniformly resample in time
all_ships = AIS_tools.resample_time_all(ship_passes)
# Out:
# 0.04089139673583086544
# /Users/jhrag/opt/anaconda3/envs/ooi_dev/lib/python3.7/site-packages/scipy/interpolate/interpolate.py:609: RuntimeWarning: divide by zero encountered in true_divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# /Users/jhrag/opt/anaconda3/envs/ooi_dev/lib/python3.7/site-packages/scipy/interpolate/interpolate.py:612: RuntimeWarning: invalid value encountered in multiply
#   y_new = slope*(x_new - x_lo)[:, None] + y_lo
# 0.045569801078532915
# /Users/jhrag/opt/anaconda3/envs/ooi_dev/lib/python3.7/site-packages/scipy/interpolate/interpolate.py:609: RuntimeWarning: invalid value encountered in true_divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# 0.999964286989750464

# %% [markdown]
# ## Build array with time bins of 1 hour

# %%
bearing, bearing_bins, time_bins = AIS_tools.get_bearing_time_histogram(all_ships, R=100, load_pkl=False)
# Out:
# 0.97018758799132454554

# %%
start = pd.Timestamp('2015-01-01').value
end = pd.Timestamp('2021-1-1').value
time_bins = np.linspace(start, end, 1000)

time_bins = pd.to_datetime(time_bins).to_list()

len(time_bins)
# Out:
# 1000

# %%
bins = np.arange(0,361)
bearing_t = df_t[(df_t['Range (km)'] < 100)]['bearing']
bearing_hist, bearing_edges = np.histogram(bearing_t, bins=bins)

# %%
plt.plot(bearing_hist)

# %%
bearing, bins = AIS_tools.get_time_histogram(load_pkl=True)

# %%
# Total Bearing Count
plt.plot(np.sum(bearing, axis=0))

# %% [markdown]
# # Looking at Lat Lon Distribution

# %%
from matplotlib.ticker import FormatStrFormatter
radius100 = all_ships[all_ships['ranges (km)'] < 100]

heatmap, xedges, yedges = np.histogram2d(radius100.lons, radius100.lats, bins=1000)



xticks = np.array([0, 200, 400, 600, 800])
yticks = np.array([0, 200, 400, 600, 800])
xlabels = np.char.mod('%.2f',xedges[xticks])
ylabels = np.char.mod('%.2f',yedges[yticks])

fig = plt.figure(figsize=(10,10))
plt.imshow(heatmap.T, vmax = 10, origin='lower')
#plt.colorbar()
plt.xticks(xticks, xlabels)
plt.yticks(yticks, ylabels)

plt.xlabel('Longitude')
plt.ylabel('Latitude')

fig.savefig('density_heatmap_resampled.png',dpi=200)

# %%
print(len(all_ships))
print(len(df))
# Out:
# 1457941
# 2003830

# %%
all_ships
# Out:
#                LAT         LON      time_val  Range (km)  SPEED (KNOTSx10)  \
# 0        46.098590 -129.655000  1.420072e+18   31.009050        108.000000
# 1        46.100263 -129.633731  1.420072e+18   32.542294        107.871795
# 2        46.101936 -129.612462  1.420073e+18   34.075537        107.743590
# 3        46.103609 -129.591192  1.420073e+18   35.608781        107.615385
# 4        46.105282 -129.569923  1.420073e+18   37.142025        107.487179
# ...            ...         ...           ...         ...               ...
# 1457936  46.820270 -128.542860  1.608459e+18  147.762315        118.785235
# 1457937  46.830167 -128.523716  1.608459e+18  149.587644        118.938462
# 1457938  46.840006 -128.504644  1.608460e+18  151.404431        120.574074
# 1457939  46.850197 -128.485349  1.608460e+18  153.259549        121.747573
# 1457940  46.860410 -128.465868  1.608460e+18  155.126867        120.620321
#
#                 MMSI  original_index    bearing
# ...

# %%
# overal distribution
full_distribution = np.sum(bearing, axis=1)
time = []
base_time = np.datetime64('2015-01-01 00:00:00')
# Get x axis labels
for k in range(52562):
    delT = np.timedelta64(k, 'h')
    time.append(pd.Timestamp(base_time + delT))
    
# make df
full_dis_df = pd.DataFrame({'dist':full_distribution, 'time':time})

fig = px.line(
    full_dis_df,
    y='dist',
    x='time',
    labels = {
        'dist':'Ship Counts per 5 min',
        'time':'Hour'
    },
    title = 'Full Distribution in Time (Range of 100 km)'
)

#fig.write_html('Full_distribution_time.html')

# %%
fig = px.imshow(bearing.T, aspect='auto', zmax = 3, x=full_dis_df['time'], y=bins[:-1]*360)
#fig.show()
fig.write_html('bearing_time_distribution.html')

# %%
# Get 201 Moving Average
kernel = np.ones(201)/201

ma_201 = np.apply_along_axis(lambda m: np.convolve(m, kernel, mode='valid'), axis=0, arr=bearing)

fig = px.imshow(ma_201.T, aspect='auto', zmax = 3, x=full_dis_df['time'][100:-100], y=bins[:-1]*360,
               labels={'x':'Time', 'y':'Bearing from North (degrees)'})
#fig.show()
fig.write_html('bearing_time_distribution_201.html')

# %%
# overal distribution
full_distribution_201 = np.sum(ma_201, axis=1)
time = []
base_time = np.datetime64('2015-01-01 00:00:00')
# Get x axis labels
for k in range(52562):
    delT = np.timedelta64(k, 'h')
    time.append(pd.Timestamp(base_time + delT))
    
time = time[100:-100]

# make df
full_dis_df = pd.DataFrame({'dist':full_distribution_201, 'time':time})

fig = px.line(
    full_dis_df,
    y='dist',
    x='time',
    labels = {
        'dist':'Ship Counts per 5 min',
        'time':'Hour'
    },
    title = 'Full Distribution in Time (Range of 100 km)'
)

fig.write_html('Full_distribution_time_201.html')
